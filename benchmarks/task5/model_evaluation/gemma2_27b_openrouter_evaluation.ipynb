# %% [markdown]
# # Region Sensitivity OpenRouter Evaluation — Prompt-matched Version
#
# This notebook is designed to match the previous Gemini evaluation notebook as closely as possible.
#
# It uses the same official QA JSON file:
#
# ```text
# region_sensitivity_outputs/region_sensitivity_qa_pairs_context_v2_1800_eval.json
# ```
#
# It also constructs the model input using the same prompt structure as the Gemini notebook:
#
# ```python
# full_prompt = (
#     system_prompt
#     + "\n\n"
#     + question
#     + "\n\nImportant instruction: Return only one option letter: A, B, C, or D. "
#     + "Do not explain your reasoning."
# )
# ```
#
# Important design choice:
#
# - OpenRouter receives this `full_prompt` as a single user message.
# - No extra OpenRouter system prompt is added.
# - Gold fields are not sent to the model.
# - The answer extraction function is copied from the Gemini notebook.

# %% [markdown]
# ## 1. Imports and paths

# %%
import os
import re
import json
import time
import random
import hashlib
import getpass
from pathlib import Path
from datetime import datetime

import pandas as pd
import requests
from tqdm import tqdm

# %%
# -----------------------------
# Paths
# -----------------------------

OUTPUT_DIR = Path("region_sensitivity_outputs")
EVAL_OUTPUT_DIR = Path("region_sensitivity_eval_outputs")
EVAL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# This should be the same official QA file used by the Gemini notebook.
OFFICIAL_QA_PATH = OUTPUT_DIR / "region_sensitivity_qa_pairs_context_v2_1800_eval.json"

# Optional debug file if you have it.
DEBUG_QA_PATH = OUTPUT_DIR / "region_sensitivity_qa_pairs_context_v2_debug_15.json"

# Use False for the official 1800-row evaluation.
# The notebook still has a 5-row dry run cell later, so you usually keep this as False.
USE_DEBUG = False

QA_PATH = DEBUG_QA_PATH if USE_DEBUG else OFFICIAL_QA_PATH

print("Official QA path:", OFFICIAL_QA_PATH)
print("Debug QA path:", DEBUG_QA_PATH)
print("Selected QA path:", QA_PATH)
print("Eval output dir:", EVAL_OUTPUT_DIR)

if not QA_PATH.exists():
    raise FileNotFoundError(
        f"Cannot find selected QA file: {QA_PATH.resolve()}\n\n"
        "This prompt-matched OpenRouter notebook expects the official JSON used by the Gemini notebook.\n"
        "Please make sure the file exists, or update OFFICIAL_QA_PATH to the correct absolute path."
    )
# Out:
# Official QA path: region_sensitivity_outputs/region_sensitivity_qa_pairs_context_v2_1800_eval.json
# Debug QA path: region_sensitivity_outputs/region_sensitivity_qa_pairs_context_v2_debug_15.json
# Selected QA path: region_sensitivity_outputs/region_sensitivity_qa_pairs_context_v2_1800_eval.json
# Eval output dir: region_sensitivity_eval_outputs

# %% [markdown]
# ## 2. Load official QA JSON
#
# This matches the Gemini notebook, which loads the official QA file from JSON.

# %%
# -----------------------------
# Load QA data
# -----------------------------

with open(QA_PATH, "r", encoding="utf-8") as f:
    qa_data = json.load(f)

eval_df = pd.DataFrame(qa_data)

print("Loaded QA:", eval_df.shape)

if "task_type" in eval_df.columns:
    print("\nTask distribution:")
    print(eval_df["task_type"].value_counts())

if "answer" in eval_df.columns:
    print("\nAnswer distribution by task:")
    print(pd.crosstab(eval_df["task_type"], eval_df["answer"]))

print("\nColumns:")
print(eval_df.columns.tolist())

display(eval_df.head(2))
# Out:
# Loaded QA: (1800, 9)
#
# Task distribution:
# task_type
# pairwise_comparison     600
# top_sensitive_region    600
# management_priority     600
# Name: count, dtype: int64
#
# Answer distribution by task:
# answer                  A    B    C    D
# task_type
# management_priority   162  157  150  131
# pairwise_comparison   293  307    0    0
# top_sensitive_region  161  144  142  153
#
# Columns:
# ['id', 'task_type', 'system_prompt', 'question', 'options', 'answer', 'gold_region', 'weather_condition', 'candidate_lgas']
#                                        id            task_type  \
# 0  rs_context_v2_pairwise_comparison_0001  pairwise_comparison
# 1  rs_context_v2_pairwise_comparison_0002  pairwise_comparison
#
#                                        system_prompt  \
# 0  You are evaluating weather-sensitive urban tra...
# 1  You are evaluating weather-sensitive urban tra...
#
#                                             question  \
# 0  Weather condition:\nno_rain+strong_wind+very_h...
# 1  Weather condition:\nlight_rain+overcast\n\nCan...
#
#                               options answer gold_region  \
# 0  {'A': 'Sydney', 'B': 'Leichhardt'}      B  Leichhardt
# 1   {'A': 'Auburn', 'B': 'Warringah'}      B   Warringah
#
#                          weather_condition        candidate_lgas
# 0  no_rain+strong_wind+very_humid+overcast  [Sydney, Leichhardt]
# 1                      light_rain+overcast   [Auburn, Warringah]

# %% [markdown]
# ## 3. Check required fields
#
# These are the same required fields as the Gemini notebook.

# %%
# -----------------------------
# Check evaluation fields
# -----------------------------

required_cols = [
    "id",
    "task_type",
    "system_prompt",
    "question",
    "answer",
    "gold_region"
]

missing_cols = [col for col in required_cols if col not in eval_df.columns]

if missing_cols:
    raise ValueError(
        f"Missing columns: {missing_cols}\n\n"
        "This means the selected QA file is not the same official JSON format used by the Gemini evaluation.\n"
        "Do not use the simplified CSV for prompt-matched multi-model evaluation."
    )

print("All required columns found.")
print("Columns in eval_df:")
print(eval_df.columns.tolist())

if not USE_DEBUG:
    assert len(eval_df) == 1800, (
        f"Official evaluation should use 1800 QA rows, but eval_df has {len(eval_df)} rows. "
        "Check that USE_DEBUG=False and the official JSON path is correct."
    )
# Out:
# All required columns found.
# Columns in eval_df:
# ['id', 'task_type', 'system_prompt', 'question', 'options', 'answer', 'gold_region', 'weather_condition', 'candidate_lgas']

# %% [markdown]
# ## 4. Build prompt exactly like the Gemini notebook

# %%
# -----------------------------
# Prompt construction
# -----------------------------

def build_full_prompt(system_prompt, question):
    """
    Build the exact same prompt string used in the Gemini notebook.

    Gemini notebook logic:
        full_prompt = (
            system_prompt
            + "\n\n"
            + question
            + "\n\nImportant instruction: Return only one option letter: A, B, C, or D. "
            + "Do not explain your reasoning."
        )
    """
    return (
        str(system_prompt)
        + "\n\n"
        + str(question)
        + "\n\nImportant instruction: Return only one option letter: A, B, C, or D. "
        + "Do not explain your reasoning."
    )


# Check the first prompt.
test_full_prompt = build_full_prompt(
    eval_df.iloc[0]["system_prompt"],
    eval_df.iloc[0]["question"]
)

print("First full prompt SHA256:")
print(hashlib.sha256(test_full_prompt.encode("utf-8")).hexdigest())

print("\nFirst full prompt preview:")
print(test_full_prompt[:3000])

print("\nGold fields are NOT included in the prompt.")
print("Gold answer for row 0, shown only for checking:", eval_df.iloc[0]["answer"])
print("Gold region for row 0, shown only for checking:", eval_df.iloc[0]["gold_region"])
# Out:
# First full prompt SHA256:
# 2a1d036b4a0d3aafbb726c5dac5fa74cfff7d0abc9781dc0a931799bd8679a81
#
# First full prompt preview:
# You are evaluating weather-sensitive urban traffic patterns using the provided regional context and traffic evidence. Use only the information provided in the question. Do not rely on external assumptions about the LGA names. A weather-sensitive traffic region is one whose observed traffic appears to deviate more strongly or more frequently from its expected traffic level under the given weather condition. Return only one option letter from the given options.
#
# Weather condition:
# no_rain+strong_wind+very_humid+overcast
#
# Candidate LGAs:
#
# A. Sydney
# - Number of traffic stations: 12
# - Average expected traffic volume: 1088.1
# - Average observed traffic volume under this weather condition: 1052.1
# - Observed traffic compared with typical level: lower than typical
# - Dominant land-use type: residential
# - POI density: high
# - Significant traffic change frequency: high
# - Typical traffic deviation magnitude: high
# - Average nearby event count within 3 km: 0.6
# - Average nearby crash count: 3.1
#
# B. Leichhardt
# - Number of traffic stations: 3
# - Average expected traffic volume: 1493.1
# - Average observed traffic volume under this weather condition: 1277.0
# - Observed traffic compared with typical level: much lower than typical
# - Dominant land-use type: residential
# - POI density: high
# - Significant traffic change frequency: high
# - Typical traffic deviation magnitude: high
# - Average nearby event count within 3 km: 0.0
# - Average nearby crash count: 3.2
#
# Question:
# Based on the regional context and traffic evidence above, which LGA appears to have more weather-sensitive traffic under no_rain+strong_wind+very_humid+overcast conditions?
#
# Options:
# A. Sydney
# B. Leichhardt
#
# Return only one option letter.
#
# Important instruction: Return only one option letter: A, B, C, or D. Do not explain your reasoning.
#
# Gold fields are NOT included in the prompt.
# Gold answer for row 0, shown only for checking: B
# Gold region for row 0, shown only for checking: Leichhardt

# %% [markdown]
# ## 5. Answer extraction
#
# This function is copied from the Gemini notebook to keep evaluation consistent.

# %%
# -----------------------------
# Extract option letter from model response
# -----------------------------

def extract_option_letter(response_text):
    """
    Extract A/B/C/D from model output.

    This function avoids taking the first option letter mentioned in the reasoning.
    It prioritises final-answer patterns such as:
    - "The final answer is C"
    - "Answer: C"
    - "\\boxed{C}"
    """

    if response_text is None:
        return None

    text = str(response_text).strip()
    upper_text = text.upper().strip()

    # Direct one-letter answer, allowing punctuation
    direct_match = re.match(r"^\s*([ABCD])\s*[\.\)]?\s*$", upper_text)
    if direct_match:
        return direct_match.group(1)

    # Normalise whitespace
    upper_text = re.sub(r"\s+", " ", upper_text)

    # LaTeX boxed answer, e.g. \boxed{C}
    boxed_match = re.search(r"\\?BOXED\{([ABCD])\}", upper_text)
    if boxed_match:
        return boxed_match.group(1)

    # Common final-answer patterns
    final_patterns = [
        r"THE FINAL ANSWER IS\s*[:\-]?\s*([ABCD])",
        r"FINAL ANSWER IS\s*[:\-]?\s*([ABCD])",
        r"FINAL ANSWER\s*[:\-]?\s*([ABCD])",
        r"THE ANSWER IS\s*[:\-]?\s*([ABCD])",
        r"ANSWER IS\s*[:\-]?\s*([ABCD])",
        r"ANSWER\s*[:\-]?\s*([ABCD])",
        r"OPTION\s*([ABCD])",
        r"CHOOSE\s*([ABCD])",
    ]

    for pattern in final_patterns:
        matches = re.findall(pattern, upper_text)
        if matches:
            return matches[-1]

    # Fallback: use the last standalone A/B/C/D, not the first.
    # This handles outputs that discuss all options before giving a final answer.
    all_matches = re.findall(r"\b([ABCD])\b", upper_text)

    if all_matches:
        return all_matches[-1]

    return None


# Quick test
test_outputs = [
    "A",
    "A.",
    "Option B",
    "The answer is C.",
    "D because ...",
    "The final answer is \\boxed{C}",
    "After comparing A, B, C, and D, the final answer is C.",
    "unknown"
]

for x in test_outputs:
    print(x, "->", extract_option_letter(x))
# Out:
# A -> A
# A. -> A
# Option B -> B
# The answer is C. -> C
# D because ... -> D
# The final answer is \boxed{C} -> C
# After comparing A, B, C, and D, the final answer is C. -> C
# unknown -> None

# %% [markdown]
# ## 6. OpenRouter configuration
#
# Default model:
#
# ```text
# google/gemma-2-27b-it
# ```
#
# This is the paid / normal endpoint. The free endpoint would have `:free` at the end, but this notebook defaults to the paid model for official evaluation.

# %%
# -----------------------------
# OpenRouter configuration
# -----------------------------

OPENROUTER_API_URL = "https://openrouter.ai/api/v1/chat/completions"

MODEL_PROVIDER = "openrouter"

# Paid / normal endpoint:
MODEL_NAME = "google/gemma-2-27b-it"

MODEL_SLUG = MODEL_NAME.replace("/", "_").replace(":", "_")

# Use a new filename to avoid mixing with the previous non-prompt-matched dry run.
SAVE_PATH = EVAL_OUTPUT_DIR / f"results_{MODEL_SLUG}_context_v2_1800_promptmatched.csv"

# For deterministic classification-style evaluation across OpenRouter models.
# Note: Gemini notebook did not explicitly set decoding parameters.
# For OpenRouter models, keep these constant across all OpenRouter evaluations.
TEMPERATURE = 0
MAX_TOKENS = 20

# Delay to reduce rate-limit risk.
SLEEP_SECONDS = 2.0

print("Model provider:", MODEL_PROVIDER)
print("Model name:", MODEL_NAME)
print("Save path:", SAVE_PATH)
# Out:
# Model provider: openrouter
# Model name: google/gemma-2-27b-it
# Save path: region_sensitivity_eval_outputs/results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv

# %% [markdown]
# ## 7. Set OpenRouter API key
#
# Do not hard-code your key into the notebook.

# %%
# -----------------------------
# API key
# -----------------------------

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

if not OPENROUTER_API_KEY:
    OPENROUTER_API_KEY = getpass.getpass("Enter your OpenRouter API key: ").strip()

if not OPENROUTER_API_KEY:
    raise ValueError("OPENROUTER_API_KEY is empty.")

print("OpenRouter API key loaded.")
# Out:
# Enter your OpenRouter API key:  ········
# OpenRouter API key loaded.

# %% [markdown]
# ## 8. OpenRouter call function
#
# Important: no extra system message is added.
#
# The model receives only the Gemini-style `full_prompt` as one user message.

# %%
# -----------------------------
# OpenRouter API call
# -----------------------------

def should_stop_run(status_code, response_text):
    """
    Detect errors where continuing would waste time or create many failed rows.
    """
    text = (response_text or "").lower()

    stop_phrases = [
        "invalid api key",
        "no auth credentials",
        "unauthorized",
        "forbidden",
        "insufficient credits",
        "credits",
        "quota",
        "rate limit",
        "too many requests",
        "payment required",
    ]

    if status_code in [401, 402, 403]:
        return True

    if any(phrase in text for phrase in stop_phrases):
        return True

    return False


def call_openrouter_model(full_prompt, model_name=MODEL_NAME, max_retries=3):
    """
    Call OpenRouter model and return raw text response.

    To match the Gemini prompt as closely as possible:
    - full_prompt is constructed using the same Gemini notebook formula.
    - full_prompt is sent as a single user message.
    - no extra OpenRouter system prompt is added.
    """

    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "Content-Type": "application/json",
        "HTTP-Referer": "https://chat.openai.com/",
        "X-Title": "Region Sensitivity Prompt-Matched Evaluation",
    }

    payload = {
        "model": model_name,
        "messages": [
            {"role": "user", "content": full_prompt}
        ],
        "temperature": TEMPERATURE,
        "max_tokens": MAX_TOKENS,
    }

    last_error = None

    for attempt in range(1, max_retries + 1):
        try:
            response = requests.post(
                OPENROUTER_API_URL,
                headers=headers,
                json=payload,
                timeout=90,
            )

            if response.status_code == 200:
                data = response.json()
                return data["choices"][0]["message"]["content"]

            response_text = response.text
            last_error = f"HTTP {response.status_code}: {response_text[:1000]}"

            if should_stop_run(response.status_code, response_text):
                raise RuntimeError(
                    "STOP_RUN: OpenRouter quota/auth/credit/rate-limit problem. "
                    f"Details: {last_error}"
                )

            if response.status_code in [429, 500, 502, 503, 504]:
                wait_time = min(60, (2 ** attempt) + random.random())
                print(f"Transient error. Retry {attempt}/{max_retries} after {wait_time:.1f}s")
                time.sleep(wait_time)
                continue

            raise RuntimeError(last_error)

        except requests.exceptions.RequestException as e:
            last_error = repr(e)
            wait_time = min(60, (2 ** attempt) + random.random())
            print(f"Request exception. Retry {attempt}/{max_retries} after {wait_time:.1f}s")
            time.sleep(wait_time)

    raise RuntimeError(f"OpenRouter request failed after retries: {last_error}")

# %% [markdown]
# ## 9. Single-call test
#
# Run this before any batch evaluation.

# %%
# -----------------------------
# Single-call test
# -----------------------------

test_row = eval_df.iloc[0]
test_prompt = build_full_prompt(
    test_row["system_prompt"],
    test_row["question"]
)

print("Testing one OpenRouter call...")
print("ID:", test_row["id"])
print("Task:", test_row["task_type"])
print("Gold answer:", test_row["answer"])

raw_response = call_openrouter_model(test_prompt)
predicted_answer = extract_option_letter(raw_response)

print("\nRaw response:")
print(raw_response)

print("\nExtracted answer:")
print(predicted_answer)

print("\nIs correct:")
print(predicted_answer == test_row["answer"])
# Out:
# Testing one OpenRouter call...
# ID: rs_context_v2_pairwise_comparison_0001
# Task: pairwise_comparison
# Gold answer: B
#
# Raw response:
#
# B
#
# Extracted answer:
# B
#
# Is correct:
# True

# %% [markdown]
# ## 10. Resume helpers
#
# Successful rows are skipped.
#
# Previous error rows are intentionally rerun.

# %%
# -----------------------------
# Resume helpers
# -----------------------------

def is_successful_result(row):
    error_value = row.get("error", None)
    pred_value = row.get("predicted_answer", None)

    error_empty = pd.isna(error_value) or str(error_value).strip() == ""
    pred_valid = str(pred_value).strip().upper() in ["A", "B", "C", "D"]

    return error_empty and pred_valid


def load_existing_successes(save_path):
    """
    Load existing output and keep only successful rows.
    Error rows are dropped so they can be rerun.
    """
    if not Path(save_path).exists():
        print("No existing result file found. Starting fresh.")
        return pd.DataFrame(), set()

    existing_df = pd.read_csv(save_path)

    if len(existing_df) == 0:
        return existing_df, set()

    if "id" not in existing_df.columns:
        raise ValueError("Existing output file does not contain 'id'. Check file compatibility.")

    success_mask = existing_df.apply(is_successful_result, axis=1)
    success_df = existing_df[success_mask].copy()
    success_ids = set(success_df["id"].astype(str).tolist())

    print(f"Existing rows: {len(existing_df)}")
    print(f"Existing successful rows kept: {len(success_df)}")
    print(f"Previous error rows to rerun: {len(existing_df) - len(success_df)}")

    return success_df, success_ids


def save_results(results, save_path=SAVE_PATH):
    result_df = pd.DataFrame(results)

    if "id" in result_df.columns:
        result_df = result_df.sort_values(by="id").reset_index(drop=True)

    result_df.to_csv(save_path, index=False)
    return result_df

# %% [markdown]
# ## 11. Main evaluation function
#
# Use `run_limit=5` first.
#
# Then use `run_limit=None` for the full remaining run.

# %%
# -----------------------------
# Main evaluation
# -----------------------------

def run_evaluation(run_limit=5, sleep_seconds=SLEEP_SECONDS):
    """
    Run OpenRouter evaluation with prompt-matched input and safe resume.

    Args:
        run_limit:
            5 for dry run.
            None for all remaining rows.
        sleep_seconds:
            Delay between successful requests.
    """

    success_df, success_ids = load_existing_successes(SAVE_PATH)

    work_df = eval_df.copy()
    work_df["id"] = work_df["id"].astype(str)

    rows_to_run = work_df[~work_df["id"].isin(success_ids)].copy()

    # Keep the original official QA order to match the Gemini evaluation order as closely as possible.
    if run_limit is not None:
        rows_to_run = rows_to_run.head(run_limit).copy()

    print("\nEvaluation setup")
    print("----------------")
    print("Model provider:", MODEL_PROVIDER)
    print("Model name:", MODEL_NAME)
    print("Total QA rows:", len(eval_df))
    print("Already successful:", len(success_ids))
    print("Rows to run now:", len(rows_to_run))
    print("Saving to:", SAVE_PATH)

    results = success_df.to_dict("records")

    if len(rows_to_run) == 0:
        print("No remaining rows to run.")
        return save_results(results, SAVE_PATH)

    for local_i, (_, row) in enumerate(rows_to_run.iterrows(), start=1):
        print(
            f"\n[{local_i}/{len(rows_to_run)}] "
            f"id={row['id']} task={row['task_type']} gold={row['answer']}"
        )

        raw_response = None
        predicted_answer = None
        error = None

        try:
            full_prompt = build_full_prompt(
                row["system_prompt"],
                row["question"]
            )

            raw_response = call_openrouter_model(
                full_prompt=full_prompt,
                model_name=MODEL_NAME,
                max_retries=3
            )

            predicted_answer = extract_option_letter(raw_response)

            result_row = {
                "id": row["id"],
                "task_type": row["task_type"],
                "weather_condition": row.get("weather_condition", None),
                "model_provider": MODEL_PROVIDER,
                "model_name": MODEL_NAME,
                "gold_answer": row["answer"],
                "gold_region": row["gold_region"],
                "raw_response": raw_response,
                "predicted_answer": predicted_answer,
                "is_correct": predicted_answer == row["answer"],
                "error": None,
                "started_at": datetime.now().isoformat(timespec="seconds"),
                "finished_at": datetime.now().isoformat(timespec="seconds"),
            }

            print("Raw response:", repr(raw_response))
            print("Parsed:", predicted_answer, "| Correct:", result_row["is_correct"])

        except Exception as e:
            error = str(e)

            result_row = {
                "id": row["id"],
                "task_type": row["task_type"],
                "weather_condition": row.get("weather_condition", None),
                "model_provider": MODEL_PROVIDER,
                "model_name": MODEL_NAME,
                "gold_answer": row["answer"],
                "gold_region": row["gold_region"],
                "raw_response": None,
                "predicted_answer": None,
                "is_correct": False,
                "error": error,
                "started_at": datetime.now().isoformat(timespec="seconds"),
                "finished_at": datetime.now().isoformat(timespec="seconds"),
            }

            print("Error:", error)

            if "STOP_RUN" in error:
                print("\nStopping evaluation to avoid writing many failed rows.")
                break

        results.append(result_row)

        # Save after every row to avoid losing progress.
        save_results(results, SAVE_PATH)

        print(f"Saved rows: {len(results)}")

        if error is None:
            time.sleep(sleep_seconds)

    results_df = save_results(results, SAVE_PATH)

    print("\nRun finished or stopped.")
    print("Saved results to:", SAVE_PATH)
    print("Total saved rows:", len(results_df))
    print("Number of errors:", results_df["error"].notna().sum())

    if len(results_df) > 0:
        print("\nOverall accuracy including errors as wrong:", results_df["is_correct"].mean())
        print("\nAccuracy by task:")
        print(results_df.groupby("task_type")["is_correct"].mean())

    return results_df

# %% [markdown]
# ## 12. Dry run: 5 rows
#
# Run this first.
#
# If `predicted_answer` is parsed as A/B/C/D and there are no errors, continue to the full run.

# %%
dry_df = run_evaluation(run_limit=5, sleep_seconds=SLEEP_SECONDS)
display(dry_df.tail())
# Out:
# No existing result file found. Starting fresh.
#
# Evaluation setup
# ----------------
# Model provider: openrouter
# Model name: google/gemma-2-27b-it
# Total QA rows: 1800
# Already successful: 0
# Rows to run now: 5
# Saving to: region_sensitivity_eval_outputs/results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv
#
# [1/5] id=rs_context_v2_pairwise_comparison_0001 task=pairwise_comparison gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1
#
# [2/5] id=rs_context_v2_pairwise_comparison_0002 task=pairwise_comparison gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 2
#
# [3/5] id=rs_context_v2_pairwise_comparison_0003 task=pairwise_comparison gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 3
#
# [4/5] id=rs_context_v2_pairwise_comparison_0004 task=pairwise_comparison gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 4
#
# [5/5] id=rs_context_v2_pairwise_comparison_0005 task=pairwise_comparison gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 5
#
# Run finished or stopped.
# Saved results to: region_sensitivity_eval_outputs/results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv
# Total saved rows: 5
# Number of errors: 0
#
# Overall accuracy including errors as wrong: 1.0
#
# Accuracy by task:
# task_type
# pairwise_comparison    1.0
# Name: is_correct, dtype: float64
#                                        id            task_type  \
# 0  rs_context_v2_pairwise_comparison_0001  pairwise_comparison
# 1  rs_context_v2_pairwise_comparison_0002  pairwise_comparison
# 2  rs_context_v2_pairwise_comparison_0003  pairwise_comparison
# 3  rs_context_v2_pairwise_comparison_0004  pairwise_comparison
# 4  rs_context_v2_pairwise_comparison_0005  pairwise_comparison
#
#                          weather_condition model_provider  \
# 0  no_rain+strong_wind+very_humid+overcast     openrouter
# 1                      light_rain+overcast     openrouter
# 2           heavy_rain+very_humid+overcast     openrouter
# 3                     no_rain+extreme_heat     openrouter
# 4                       no_rain+very_humid     openrouter
#
#               model_name gold_answer gold_region raw_response  \
# 0  google/gemma-2-27b-it           B  Leichhardt          \nB
# 1  google/gemma-2-27b-it           B   Warringah          \nB
# 2  google/gemma-2-27b-it           B  Parramatta          \nB
# 3  google/gemma-2-27b-it           B  Parramatta          \nB
# 4  google/gemma-2-27b-it           B   Warringah          \nB
#
#   predicted_answer  is_correct error           started_at          finished_at
# 0                B        True  None  2026-07-10T15:09:54  2026-07-10T15:09:54
# 1                B        True  None  2026-07-10T15:09:57  2026-07-10T15:09:57
# 2                B        True  None  2026-07-10T15:10:00  2026-07-10T15:10:00
# 3                B        True  None  2026-07-10T15:10:04  2026-07-10T15:10:04
# 4                B        True  None  2026-07-10T15:10:07  2026-07-10T15:10:07

# %% [markdown]
# ## 13. Check dry-run summary

# %%
if SAVE_PATH.exists():
    check_df = pd.read_csv(SAVE_PATH)

    print("Rows saved:", len(check_df))
    print("Errors:", check_df["error"].notna().sum())

    print("\nPrediction distribution:")
    print(check_df["predicted_answer"].value_counts(dropna=False).sort_index())

    print("\nAccuracy so far:")
    print(check_df["is_correct"].mean())

    print("\nAccuracy by task:")
    print(check_df.groupby("task_type")["is_correct"].mean())
# Out:
# Rows saved: 5
# Errors: 0
#
# Prediction distribution:
# predicted_answer
# B    5
# Name: count, dtype: int64
#
# Accuracy so far:
# 1.0
#
# Accuracy by task:
# task_type
# pairwise_comparison    1.0
# Name: is_correct, dtype: float64

# %% [markdown]
# ## 14. Full run: all remaining rows
#
# Only run this after the 5-row dry run looks correct.
#
# This will resume from the existing output file and skip successful rows.

# %%
# Full run.
# If the 5 dry-run rows were successful, this will skip them and run the remaining 1795 rows.
full_df = run_evaluation(run_limit=None, sleep_seconds=SLEEP_SECONDS)
display(full_df.tail())
# Out:
# Existing rows: 1331
# Existing successful rows kept: 1331
# Previous error rows to rerun: 0
#
# Evaluation setup
# ----------------
# Model provider: openrouter
# Model name: google/gemma-2-27b-it
# Total QA rows: 1800
# Already successful: 1331
# Rows to run now: 469
# Saving to: region_sensitivity_eval_outputs/results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv
#
# [1/469] id=rs_context_v2_management_priority_0132 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1332
#
# [2/469] id=rs_context_v2_management_priority_0133 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1333
#
# [3/469] id=rs_context_v2_management_priority_0134 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1334
#
# [4/469] id=rs_context_v2_management_priority_0135 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1335
#
# [5/469] id=rs_context_v2_management_priority_0136 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1336
#
# [6/469] id=rs_context_v2_management_priority_0137 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1337
#
# [7/469] id=rs_context_v2_management_priority_0138 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1338
#
# [8/469] id=rs_context_v2_management_priority_0139 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1339
#
# [9/469] id=rs_context_v2_management_priority_0140 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1340
#
# [10/469] id=rs_context_v2_management_priority_0141 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1341
#
# [11/469] id=rs_context_v2_management_priority_0142 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1342
#
# [12/469] id=rs_context_v2_management_priority_0143 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1343
#
# [13/469] id=rs_context_v2_management_priority_0144 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1344
#
# [14/469] id=rs_context_v2_management_priority_0145 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1345
#
# [15/469] id=rs_context_v2_management_priority_0146 task=management_priority gold=C
# Raw response: '\nD \n'
# Parsed: D | Correct: False
# Saved rows: 1346
#
# [16/469] id=rs_context_v2_management_priority_0147 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1347
#
# [17/469] id=rs_context_v2_management_priority_0148 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1348
#
# [18/469] id=rs_context_v2_management_priority_0149 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1349
#
# [19/469] id=rs_context_v2_management_priority_0150 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1350
#
# [20/469] id=rs_context_v2_management_priority_0151 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1351
#
# [21/469] id=rs_context_v2_management_priority_0152 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1352
#
# [22/469] id=rs_context_v2_management_priority_0153 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1353
#
# [23/469] id=rs_context_v2_management_priority_0154 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1354
#
# [24/469] id=rs_context_v2_management_priority_0155 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1355
#
# [25/469] id=rs_context_v2_management_priority_0156 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1356
#
# [26/469] id=rs_context_v2_management_priority_0157 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1357
#
# [27/469] id=rs_context_v2_management_priority_0158 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1358
#
# [28/469] id=rs_context_v2_management_priority_0159 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1359
#
# [29/469] id=rs_context_v2_management_priority_0160 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1360
#
# [30/469] id=rs_context_v2_management_priority_0161 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1361
#
# [31/469] id=rs_context_v2_management_priority_0162 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1362
#
# [32/469] id=rs_context_v2_management_priority_0163 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1363
#
# [33/469] id=rs_context_v2_management_priority_0164 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1364
#
# [34/469] id=rs_context_v2_management_priority_0165 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1365
#
# [35/469] id=rs_context_v2_management_priority_0166 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1366
#
# [36/469] id=rs_context_v2_management_priority_0167 task=management_priority gold=A
# Raw response: '\nD \n'
# Parsed: D | Correct: False
# Saved rows: 1367
#
# [37/469] id=rs_context_v2_management_priority_0168 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1368
#
# [38/469] id=rs_context_v2_management_priority_0169 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1369
#
# [39/469] id=rs_context_v2_management_priority_0170 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1370
#
# [40/469] id=rs_context_v2_management_priority_0171 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1371
#
# [41/469] id=rs_context_v2_management_priority_0172 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1372
#
# [42/469] id=rs_context_v2_management_priority_0173 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1373
#
# [43/469] id=rs_context_v2_management_priority_0174 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1374
#
# [44/469] id=rs_context_v2_management_priority_0175 task=management_priority gold=D
# Raw response: '\nD \n'
# Parsed: D | Correct: True
# Saved rows: 1375
#
# [45/469] id=rs_context_v2_management_priority_0176 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1376
#
# [46/469] id=rs_context_v2_management_priority_0177 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1377
#
# [47/469] id=rs_context_v2_management_priority_0178 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1378
#
# [48/469] id=rs_context_v2_management_priority_0179 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1379
#
# [49/469] id=rs_context_v2_management_priority_0180 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1380
#
# [50/469] id=rs_context_v2_management_priority_0181 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1381
#
# [51/469] id=rs_context_v2_management_priority_0182 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1382
#
# [52/469] id=rs_context_v2_management_priority_0183 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1383
#
# [53/469] id=rs_context_v2_management_priority_0184 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1384
#
# [54/469] id=rs_context_v2_management_priority_0185 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1385
#
# [55/469] id=rs_context_v2_management_priority_0186 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1386
#
# [56/469] id=rs_context_v2_management_priority_0187 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1387
#
# [57/469] id=rs_context_v2_management_priority_0188 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1388
#
# [58/469] id=rs_context_v2_management_priority_0189 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1389
#
# [59/469] id=rs_context_v2_management_priority_0190 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1390
#
# [60/469] id=rs_context_v2_management_priority_0191 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1391
#
# [61/469] id=rs_context_v2_management_priority_0192 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1392
#
# [62/469] id=rs_context_v2_management_priority_0193 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1393
#
# [63/469] id=rs_context_v2_management_priority_0194 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1394
#
# [64/469] id=rs_context_v2_management_priority_0195 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1395
#
# [65/469] id=rs_context_v2_management_priority_0196 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1396
#
# [66/469] id=rs_context_v2_management_priority_0197 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1397
#
# [67/469] id=rs_context_v2_management_priority_0198 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1398
#
# [68/469] id=rs_context_v2_management_priority_0199 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1399
#
# [69/469] id=rs_context_v2_management_priority_0200 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1400
#
# [70/469] id=rs_context_v2_management_priority_0201 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1401
#
# [71/469] id=rs_context_v2_management_priority_0202 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1402
#
# [72/469] id=rs_context_v2_management_priority_0203 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1403
#
# [73/469] id=rs_context_v2_management_priority_0204 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1404
#
# [74/469] id=rs_context_v2_management_priority_0205 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1405
#
# [75/469] id=rs_context_v2_management_priority_0206 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1406
#
# [76/469] id=rs_context_v2_management_priority_0207 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1407
#
# [77/469] id=rs_context_v2_management_priority_0208 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1408
#
# [78/469] id=rs_context_v2_management_priority_0209 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1409
#
# [79/469] id=rs_context_v2_management_priority_0210 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1410
#
# [80/469] id=rs_context_v2_management_priority_0211 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1411
#
# [81/469] id=rs_context_v2_management_priority_0212 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1412
#
# [82/469] id=rs_context_v2_management_priority_0213 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1413
#
# [83/469] id=rs_context_v2_management_priority_0214 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1414
#
# [84/469] id=rs_context_v2_management_priority_0215 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1415
#
# [85/469] id=rs_context_v2_management_priority_0216 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1416
#
# [86/469] id=rs_context_v2_management_priority_0217 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1417
#
# [87/469] id=rs_context_v2_management_priority_0218 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1418
#
# [88/469] id=rs_context_v2_management_priority_0219 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1419
#
# [89/469] id=rs_context_v2_management_priority_0220 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1420
#
# [90/469] id=rs_context_v2_management_priority_0221 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1421
#
# [91/469] id=rs_context_v2_management_priority_0222 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1422
#
# [92/469] id=rs_context_v2_management_priority_0223 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1423
#
# [93/469] id=rs_context_v2_management_priority_0224 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1424
#
# [94/469] id=rs_context_v2_management_priority_0225 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1425
#
# [95/469] id=rs_context_v2_management_priority_0226 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1426
#
# [96/469] id=rs_context_v2_management_priority_0227 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1427
#
# [97/469] id=rs_context_v2_management_priority_0228 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1428
#
# [98/469] id=rs_context_v2_management_priority_0229 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1429
#
# [99/469] id=rs_context_v2_management_priority_0230 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1430
#
# [100/469] id=rs_context_v2_management_priority_0231 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1431
#
# [101/469] id=rs_context_v2_management_priority_0232 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1432
#
# [102/469] id=rs_context_v2_management_priority_0233 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1433
#
# [103/469] id=rs_context_v2_management_priority_0234 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1434
#
# [104/469] id=rs_context_v2_management_priority_0235 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1435
#
# [105/469] id=rs_context_v2_management_priority_0236 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1436
#
# [106/469] id=rs_context_v2_management_priority_0237 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1437
#
# [107/469] id=rs_context_v2_management_priority_0238 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1438
#
# [108/469] id=rs_context_v2_management_priority_0239 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1439
#
# [109/469] id=rs_context_v2_management_priority_0240 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1440
#
# [110/469] id=rs_context_v2_management_priority_0241 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1441
#
# [111/469] id=rs_context_v2_management_priority_0242 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1442
#
# [112/469] id=rs_context_v2_management_priority_0243 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1443
#
# [113/469] id=rs_context_v2_management_priority_0244 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1444
#
# [114/469] id=rs_context_v2_management_priority_0245 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1445
#
# [115/469] id=rs_context_v2_management_priority_0246 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1446
#
# [116/469] id=rs_context_v2_management_priority_0247 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1447
#
# [117/469] id=rs_context_v2_management_priority_0248 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1448
#
# [118/469] id=rs_context_v2_management_priority_0249 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1449
#
# [119/469] id=rs_context_v2_management_priority_0250 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1450
#
# [120/469] id=rs_context_v2_management_priority_0251 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1451
#
# [121/469] id=rs_context_v2_management_priority_0252 task=management_priority gold=C
# Raw response: '\nD \n'
# Parsed: D | Correct: False
# Saved rows: 1452
#
# [122/469] id=rs_context_v2_management_priority_0253 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1453
#
# [123/469] id=rs_context_v2_management_priority_0254 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1454
#
# [124/469] id=rs_context_v2_management_priority_0255 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1455
#
# [125/469] id=rs_context_v2_management_priority_0256 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1456
#
# [126/469] id=rs_context_v2_management_priority_0257 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1457
#
# [127/469] id=rs_context_v2_management_priority_0258 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1458
#
# [128/469] id=rs_context_v2_management_priority_0259 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1459
#
# [129/469] id=rs_context_v2_management_priority_0260 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1460
#
# [130/469] id=rs_context_v2_management_priority_0261 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1461
#
# [131/469] id=rs_context_v2_management_priority_0262 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1462
#
# [132/469] id=rs_context_v2_management_priority_0263 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1463
#
# [133/469] id=rs_context_v2_management_priority_0264 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1464
#
# [134/469] id=rs_context_v2_management_priority_0265 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1465
#
# [135/469] id=rs_context_v2_management_priority_0266 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1466
#
# [136/469] id=rs_context_v2_management_priority_0267 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1467
#
# [137/469] id=rs_context_v2_management_priority_0268 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1468
#
# [138/469] id=rs_context_v2_management_priority_0269 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1469
#
# [139/469] id=rs_context_v2_management_priority_0270 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1470
#
# [140/469] id=rs_context_v2_management_priority_0271 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1471
#
# [141/469] id=rs_context_v2_management_priority_0272 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1472
#
# [142/469] id=rs_context_v2_management_priority_0273 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1473
#
# [143/469] id=rs_context_v2_management_priority_0274 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1474
#
# [144/469] id=rs_context_v2_management_priority_0275 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1475
#
# [145/469] id=rs_context_v2_management_priority_0276 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1476
#
# [146/469] id=rs_context_v2_management_priority_0277 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1477
#
# [147/469] id=rs_context_v2_management_priority_0278 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1478
#
# [148/469] id=rs_context_v2_management_priority_0279 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1479
#
# [149/469] id=rs_context_v2_management_priority_0280 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1480
#
# [150/469] id=rs_context_v2_management_priority_0281 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1481
#
# [151/469] id=rs_context_v2_management_priority_0282 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1482
#
# [152/469] id=rs_context_v2_management_priority_0283 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1483
#
# [153/469] id=rs_context_v2_management_priority_0284 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1484
#
# [154/469] id=rs_context_v2_management_priority_0285 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1485
#
# [155/469] id=rs_context_v2_management_priority_0286 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1486
#
# [156/469] id=rs_context_v2_management_priority_0287 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1487
#
# [157/469] id=rs_context_v2_management_priority_0288 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1488
#
# [158/469] id=rs_context_v2_management_priority_0289 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1489
#
# [159/469] id=rs_context_v2_management_priority_0290 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1490
#
# [160/469] id=rs_context_v2_management_priority_0291 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1491
#
# [161/469] id=rs_context_v2_management_priority_0292 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1492
#
# [162/469] id=rs_context_v2_management_priority_0293 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1493
#
# [163/469] id=rs_context_v2_management_priority_0294 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1494
#
# [164/469] id=rs_context_v2_management_priority_0295 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1495
#
# [165/469] id=rs_context_v2_management_priority_0296 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1496
#
# [166/469] id=rs_context_v2_management_priority_0297 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1497
#
# [167/469] id=rs_context_v2_management_priority_0298 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1498
#
# [168/469] id=rs_context_v2_management_priority_0299 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1499
#
# [169/469] id=rs_context_v2_management_priority_0300 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1500
#
# [170/469] id=rs_context_v2_management_priority_0301 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1501
#
# [171/469] id=rs_context_v2_management_priority_0302 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1502
#
# [172/469] id=rs_context_v2_management_priority_0303 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1503
#
# [173/469] id=rs_context_v2_management_priority_0304 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1504
#
# [174/469] id=rs_context_v2_management_priority_0305 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1505
#
# [175/469] id=rs_context_v2_management_priority_0306 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1506
#
# [176/469] id=rs_context_v2_management_priority_0307 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1507
#
# [177/469] id=rs_context_v2_management_priority_0308 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1508
#
# [178/469] id=rs_context_v2_management_priority_0309 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1509
#
# [179/469] id=rs_context_v2_management_priority_0310 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1510
#
# [180/469] id=rs_context_v2_management_priority_0311 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1511
#
# [181/469] id=rs_context_v2_management_priority_0312 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1512
#
# [182/469] id=rs_context_v2_management_priority_0313 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1513
#
# [183/469] id=rs_context_v2_management_priority_0314 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1514
#
# [184/469] id=rs_context_v2_management_priority_0315 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1515
#
# [185/469] id=rs_context_v2_management_priority_0316 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1516
#
# [186/469] id=rs_context_v2_management_priority_0317 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1517
#
# [187/469] id=rs_context_v2_management_priority_0318 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1518
#
# [188/469] id=rs_context_v2_management_priority_0319 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1519
#
# [189/469] id=rs_context_v2_management_priority_0320 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1520
#
# [190/469] id=rs_context_v2_management_priority_0321 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1521
#
# [191/469] id=rs_context_v2_management_priority_0322 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1522
#
# [192/469] id=rs_context_v2_management_priority_0323 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1523
#
# [193/469] id=rs_context_v2_management_priority_0324 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1524
#
# [194/469] id=rs_context_v2_management_priority_0325 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1525
#
# [195/469] id=rs_context_v2_management_priority_0326 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1526
#
# [196/469] id=rs_context_v2_management_priority_0327 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1527
#
# [197/469] id=rs_context_v2_management_priority_0328 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1528
#
# [198/469] id=rs_context_v2_management_priority_0329 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1529
#
# [199/469] id=rs_context_v2_management_priority_0330 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1530
#
# [200/469] id=rs_context_v2_management_priority_0331 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1531
#
# [201/469] id=rs_context_v2_management_priority_0332 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1532
#
# [202/469] id=rs_context_v2_management_priority_0333 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1533
#
# [203/469] id=rs_context_v2_management_priority_0334 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1534
#
# [204/469] id=rs_context_v2_management_priority_0335 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1535
#
# [205/469] id=rs_context_v2_management_priority_0336 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1536
#
# [206/469] id=rs_context_v2_management_priority_0337 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1537
#
# [207/469] id=rs_context_v2_management_priority_0338 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1538
#
# [208/469] id=rs_context_v2_management_priority_0339 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1539
#
# [209/469] id=rs_context_v2_management_priority_0340 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1540
#
# [210/469] id=rs_context_v2_management_priority_0341 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1541
#
# [211/469] id=rs_context_v2_management_priority_0342 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1542
#
# [212/469] id=rs_context_v2_management_priority_0343 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1543
#
# [213/469] id=rs_context_v2_management_priority_0344 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1544
#
# [214/469] id=rs_context_v2_management_priority_0345 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1545
#
# [215/469] id=rs_context_v2_management_priority_0346 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1546
#
# [216/469] id=rs_context_v2_management_priority_0347 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1547
#
# [217/469] id=rs_context_v2_management_priority_0348 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1548
#
# [218/469] id=rs_context_v2_management_priority_0349 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1549
#
# [219/469] id=rs_context_v2_management_priority_0350 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1550
#
# [220/469] id=rs_context_v2_management_priority_0351 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1551
#
# [221/469] id=rs_context_v2_management_priority_0352 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1552
#
# [222/469] id=rs_context_v2_management_priority_0353 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1553
#
# [223/469] id=rs_context_v2_management_priority_0354 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1554
#
# [224/469] id=rs_context_v2_management_priority_0355 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1555
#
# [225/469] id=rs_context_v2_management_priority_0356 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1556
#
# [226/469] id=rs_context_v2_management_priority_0357 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1557
#
# [227/469] id=rs_context_v2_management_priority_0358 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1558
#
# [228/469] id=rs_context_v2_management_priority_0359 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1559
#
# [229/469] id=rs_context_v2_management_priority_0360 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1560
#
# [230/469] id=rs_context_v2_management_priority_0361 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1561
#
# [231/469] id=rs_context_v2_management_priority_0362 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1562
#
# [232/469] id=rs_context_v2_management_priority_0363 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1563
#
# [233/469] id=rs_context_v2_management_priority_0364 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1564
#
# [234/469] id=rs_context_v2_management_priority_0365 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1565
#
# [235/469] id=rs_context_v2_management_priority_0366 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1566
#
# [236/469] id=rs_context_v2_management_priority_0367 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1567
#
# [237/469] id=rs_context_v2_management_priority_0368 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1568
#
# [238/469] id=rs_context_v2_management_priority_0369 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1569
#
# [239/469] id=rs_context_v2_management_priority_0370 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1570
#
# [240/469] id=rs_context_v2_management_priority_0371 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1571
#
# [241/469] id=rs_context_v2_management_priority_0372 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1572
#
# [242/469] id=rs_context_v2_management_priority_0373 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1573
#
# [243/469] id=rs_context_v2_management_priority_0374 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1574
#
# [244/469] id=rs_context_v2_management_priority_0375 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1575
#
# [245/469] id=rs_context_v2_management_priority_0376 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1576
#
# [246/469] id=rs_context_v2_management_priority_0377 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1577
#
# [247/469] id=rs_context_v2_management_priority_0378 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1578
#
# [248/469] id=rs_context_v2_management_priority_0379 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1579
#
# [249/469] id=rs_context_v2_management_priority_0380 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1580
#
# [250/469] id=rs_context_v2_management_priority_0381 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1581
#
# [251/469] id=rs_context_v2_management_priority_0382 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1582
#
# [252/469] id=rs_context_v2_management_priority_0383 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1583
#
# [253/469] id=rs_context_v2_management_priority_0384 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1584
#
# [254/469] id=rs_context_v2_management_priority_0385 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1585
#
# [255/469] id=rs_context_v2_management_priority_0386 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1586
#
# [256/469] id=rs_context_v2_management_priority_0387 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1587
#
# [257/469] id=rs_context_v2_management_priority_0388 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1588
#
# [258/469] id=rs_context_v2_management_priority_0389 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1589
#
# [259/469] id=rs_context_v2_management_priority_0390 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1590
#
# [260/469] id=rs_context_v2_management_priority_0391 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1591
#
# [261/469] id=rs_context_v2_management_priority_0392 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1592
#
# [262/469] id=rs_context_v2_management_priority_0393 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1593
#
# [263/469] id=rs_context_v2_management_priority_0394 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1594
#
# [264/469] id=rs_context_v2_management_priority_0395 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1595
#
# [265/469] id=rs_context_v2_management_priority_0396 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1596
#
# [266/469] id=rs_context_v2_management_priority_0397 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1597
#
# [267/469] id=rs_context_v2_management_priority_0398 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1598
#
# [268/469] id=rs_context_v2_management_priority_0399 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1599
#
# [269/469] id=rs_context_v2_management_priority_0400 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1600
#
# [270/469] id=rs_context_v2_management_priority_0401 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1601
#
# [271/469] id=rs_context_v2_management_priority_0402 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1602
#
# [272/469] id=rs_context_v2_management_priority_0403 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1603
#
# [273/469] id=rs_context_v2_management_priority_0404 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1604
#
# [274/469] id=rs_context_v2_management_priority_0405 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1605
#
# [275/469] id=rs_context_v2_management_priority_0406 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1606
#
# [276/469] id=rs_context_v2_management_priority_0407 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1607
#
# [277/469] id=rs_context_v2_management_priority_0408 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1608
#
# [278/469] id=rs_context_v2_management_priority_0409 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1609
#
# [279/469] id=rs_context_v2_management_priority_0410 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1610
#
# [280/469] id=rs_context_v2_management_priority_0411 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1611
#
# [281/469] id=rs_context_v2_management_priority_0412 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1612
#
# [282/469] id=rs_context_v2_management_priority_0413 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1613
#
# [283/469] id=rs_context_v2_management_priority_0414 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1614
#
# [284/469] id=rs_context_v2_management_priority_0415 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1615
#
# [285/469] id=rs_context_v2_management_priority_0416 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1616
#
# [286/469] id=rs_context_v2_management_priority_0417 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1617
#
# [287/469] id=rs_context_v2_management_priority_0418 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1618
#
# [288/469] id=rs_context_v2_management_priority_0419 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1619
#
# [289/469] id=rs_context_v2_management_priority_0420 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1620
#
# [290/469] id=rs_context_v2_management_priority_0421 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1621
#
# [291/469] id=rs_context_v2_management_priority_0422 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1622
#
# [292/469] id=rs_context_v2_management_priority_0423 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1623
#
# [293/469] id=rs_context_v2_management_priority_0424 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1624
#
# [294/469] id=rs_context_v2_management_priority_0425 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1625
#
# [295/469] id=rs_context_v2_management_priority_0426 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1626
#
# [296/469] id=rs_context_v2_management_priority_0427 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1627
#
# [297/469] id=rs_context_v2_management_priority_0428 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1628
#
# [298/469] id=rs_context_v2_management_priority_0429 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1629
#
# [299/469] id=rs_context_v2_management_priority_0430 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1630
#
# [300/469] id=rs_context_v2_management_priority_0431 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1631
#
# [301/469] id=rs_context_v2_management_priority_0432 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1632
#
# [302/469] id=rs_context_v2_management_priority_0433 task=management_priority gold=C
# Raw response: '\nD \n'
# Parsed: D | Correct: False
# Saved rows: 1633
#
# [303/469] id=rs_context_v2_management_priority_0434 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1634
#
# [304/469] id=rs_context_v2_management_priority_0435 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1635
#
# [305/469] id=rs_context_v2_management_priority_0436 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1636
#
# [306/469] id=rs_context_v2_management_priority_0437 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1637
#
# [307/469] id=rs_context_v2_management_priority_0438 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1638
#
# [308/469] id=rs_context_v2_management_priority_0439 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1639
#
# [309/469] id=rs_context_v2_management_priority_0440 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1640
#
# [310/469] id=rs_context_v2_management_priority_0441 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1641
#
# [311/469] id=rs_context_v2_management_priority_0442 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1642
#
# [312/469] id=rs_context_v2_management_priority_0443 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1643
#
# [313/469] id=rs_context_v2_management_priority_0444 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1644
#
# [314/469] id=rs_context_v2_management_priority_0445 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1645
#
# [315/469] id=rs_context_v2_management_priority_0446 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1646
#
# [316/469] id=rs_context_v2_management_priority_0447 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1647
#
# [317/469] id=rs_context_v2_management_priority_0448 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1648
#
# [318/469] id=rs_context_v2_management_priority_0449 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1649
#
# [319/469] id=rs_context_v2_management_priority_0450 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1650
#
# [320/469] id=rs_context_v2_management_priority_0451 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1651
#
# [321/469] id=rs_context_v2_management_priority_0452 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1652
#
# [322/469] id=rs_context_v2_management_priority_0453 task=management_priority gold=C
# ...
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1707
#
# [377/469] id=rs_context_v2_management_priority_0508 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1708
#
# [378/469] id=rs_context_v2_management_priority_0509 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1709
#
# [379/469] id=rs_context_v2_management_priority_0510 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1710
#
# [380/469] id=rs_context_v2_management_priority_0511 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1711
#
# [381/469] id=rs_context_v2_management_priority_0512 task=management_priority gold=A
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1712
#
# [382/469] id=rs_context_v2_management_priority_0513 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1713
#
# [383/469] id=rs_context_v2_management_priority_0514 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1714
#
# [384/469] id=rs_context_v2_management_priority_0515 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1715
#
# [385/469] id=rs_context_v2_management_priority_0516 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1716
#
# [386/469] id=rs_context_v2_management_priority_0517 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1717
#
# [387/469] id=rs_context_v2_management_priority_0518 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1718
#
# [388/469] id=rs_context_v2_management_priority_0519 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1719
#
# [389/469] id=rs_context_v2_management_priority_0520 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1720
#
# [390/469] id=rs_context_v2_management_priority_0521 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1721
#
# [391/469] id=rs_context_v2_management_priority_0522 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1722
#
# [392/469] id=rs_context_v2_management_priority_0523 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1723
#
# [393/469] id=rs_context_v2_management_priority_0524 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1724
#
# [394/469] id=rs_context_v2_management_priority_0525 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1725
#
# [395/469] id=rs_context_v2_management_priority_0526 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1726
#
# [396/469] id=rs_context_v2_management_priority_0527 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1727
#
# [397/469] id=rs_context_v2_management_priority_0528 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1728
#
# [398/469] id=rs_context_v2_management_priority_0529 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1729
#
# [399/469] id=rs_context_v2_management_priority_0530 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1730
#
# [400/469] id=rs_context_v2_management_priority_0531 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1731
#
# [401/469] id=rs_context_v2_management_priority_0532 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1732
#
# [402/469] id=rs_context_v2_management_priority_0533 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1733
#
# [403/469] id=rs_context_v2_management_priority_0534 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1734
#
# [404/469] id=rs_context_v2_management_priority_0535 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1735
#
# [405/469] id=rs_context_v2_management_priority_0536 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1736
#
# [406/469] id=rs_context_v2_management_priority_0537 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1737
#
# [407/469] id=rs_context_v2_management_priority_0538 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1738
#
# [408/469] id=rs_context_v2_management_priority_0539 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1739
#
# [409/469] id=rs_context_v2_management_priority_0540 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1740
#
# [410/469] id=rs_context_v2_management_priority_0541 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1741
#
# [411/469] id=rs_context_v2_management_priority_0542 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1742
#
# [412/469] id=rs_context_v2_management_priority_0543 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1743
#
# [413/469] id=rs_context_v2_management_priority_0544 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1744
#
# [414/469] id=rs_context_v2_management_priority_0545 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1745
#
# [415/469] id=rs_context_v2_management_priority_0546 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1746
#
# [416/469] id=rs_context_v2_management_priority_0547 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1747
#
# [417/469] id=rs_context_v2_management_priority_0548 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1748
#
# [418/469] id=rs_context_v2_management_priority_0549 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1749
#
# [419/469] id=rs_context_v2_management_priority_0550 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1750
#
# [420/469] id=rs_context_v2_management_priority_0551 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1751
#
# [421/469] id=rs_context_v2_management_priority_0552 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1752
#
# [422/469] id=rs_context_v2_management_priority_0553 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1753
#
# [423/469] id=rs_context_v2_management_priority_0554 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1754
#
# [424/469] id=rs_context_v2_management_priority_0555 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1755
#
# [425/469] id=rs_context_v2_management_priority_0556 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1756
#
# [426/469] id=rs_context_v2_management_priority_0557 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1757
#
# [427/469] id=rs_context_v2_management_priority_0558 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1758
#
# [428/469] id=rs_context_v2_management_priority_0559 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1759
#
# [429/469] id=rs_context_v2_management_priority_0560 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1760
#
# [430/469] id=rs_context_v2_management_priority_0561 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1761
#
# [431/469] id=rs_context_v2_management_priority_0562 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1762
#
# [432/469] id=rs_context_v2_management_priority_0563 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1763
#
# [433/469] id=rs_context_v2_management_priority_0564 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1764
#
# [434/469] id=rs_context_v2_management_priority_0565 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1765
#
# [435/469] id=rs_context_v2_management_priority_0566 task=management_priority gold=B
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1766
#
# [436/469] id=rs_context_v2_management_priority_0567 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1767
#
# [437/469] id=rs_context_v2_management_priority_0568 task=management_priority gold=D
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1768
#
# [438/469] id=rs_context_v2_management_priority_0569 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1769
#
# [439/469] id=rs_context_v2_management_priority_0570 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1770
#
# [440/469] id=rs_context_v2_management_priority_0571 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1771
#
# [441/469] id=rs_context_v2_management_priority_0572 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1772
#
# [442/469] id=rs_context_v2_management_priority_0573 task=management_priority gold=D
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1773
#
# [443/469] id=rs_context_v2_management_priority_0574 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1774
#
# [444/469] id=rs_context_v2_management_priority_0575 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1775
#
# [445/469] id=rs_context_v2_management_priority_0576 task=management_priority gold=B
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1776
#
# [446/469] id=rs_context_v2_management_priority_0577 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1777
#
# [447/469] id=rs_context_v2_management_priority_0578 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1778
#
# [448/469] id=rs_context_v2_management_priority_0579 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1779
#
# [449/469] id=rs_context_v2_management_priority_0580 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1780
#
# [450/469] id=rs_context_v2_management_priority_0581 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1781
#
# [451/469] id=rs_context_v2_management_priority_0582 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1782
#
# [452/469] id=rs_context_v2_management_priority_0583 task=management_priority gold=A
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1783
#
# [453/469] id=rs_context_v2_management_priority_0584 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1784
#
# [454/469] id=rs_context_v2_management_priority_0585 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1785
#
# [455/469] id=rs_context_v2_management_priority_0586 task=management_priority gold=D
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1786
#
# [456/469] id=rs_context_v2_management_priority_0587 task=management_priority gold=A
# Raw response: '\nA'
# Parsed: A | Correct: True
# Saved rows: 1787
#
# [457/469] id=rs_context_v2_management_priority_0588 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1788
#
# [458/469] id=rs_context_v2_management_priority_0589 task=management_priority gold=C
# Raw response: '\nB'
# Parsed: B | Correct: False
# Saved rows: 1789
#
# [459/469] id=rs_context_v2_management_priority_0590 task=management_priority gold=B
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1790
#
# [460/469] id=rs_context_v2_management_priority_0591 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1791
#
# [461/469] id=rs_context_v2_management_priority_0592 task=management_priority gold=C
# Raw response: '\nD'
# Parsed: D | Correct: False
# Saved rows: 1792
#
# [462/469] id=rs_context_v2_management_priority_0593 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1793
#
# [463/469] id=rs_context_v2_management_priority_0594 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1794
#
# [464/469] id=rs_context_v2_management_priority_0595 task=management_priority gold=D
# Raw response: '\nD'
# Parsed: D | Correct: True
# Saved rows: 1795
#
# [465/469] id=rs_context_v2_management_priority_0596 task=management_priority gold=C
# Raw response: '\nA'
# Parsed: A | Correct: False
# Saved rows: 1796
#
# [466/469] id=rs_context_v2_management_priority_0597 task=management_priority gold=A
# Raw response: '\nC'
# Parsed: C | Correct: False
# Saved rows: 1797
#
# [467/469] id=rs_context_v2_management_priority_0598 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1798
#
# [468/469] id=rs_context_v2_management_priority_0599 task=management_priority gold=C
# Raw response: '\nC'
# Parsed: C | Correct: True
# Saved rows: 1799
#
# [469/469] id=rs_context_v2_management_priority_0600 task=management_priority gold=B
# Raw response: '\nB'
# Parsed: B | Correct: True
# Saved rows: 1800
#
# Run finished or stopped.
# Saved results to: region_sensitivity_eval_outputs/results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv
# Total saved rows: 1800
# Number of errors: 0
#
# Overall accuracy including errors as wrong: 0.6072222222222222
#
# Accuracy by task:
# task_type
# management_priority     0.541667
# pairwise_comparison     0.760000
# top_sensitive_region    0.520000
# Name: is_correct, dtype: float64
#                                            id             task_type  \
# 1795  rs_context_v2_top_sensitive_region_0596  top_sensitive_region
# 1796  rs_context_v2_top_sensitive_region_0597  top_sensitive_region
# 1797  rs_context_v2_top_sensitive_region_0598  top_sensitive_region
# 1798  rs_context_v2_top_sensitive_region_0599  top_sensitive_region
# 1799  rs_context_v2_top_sensitive_region_0600  top_sensitive_region
#
#                    weather_condition model_provider             model_name  \
# 1795  light_rain+very_humid+overcast     openrouter  google/gemma-2-27b-it
# 1796              no_rain+very_humid     openrouter  google/gemma-2-27b-it
# 1797    no_rain+strong_wind+overcast     openrouter  google/gemma-2-27b-it
# 1798           light_rain+very_humid     openrouter  google/gemma-2-27b-it
# 1799        moderate_rain+very_humid     openrouter  google/gemma-2-27b-it
#
#      gold_answer  gold_region raw_response predicted_answer  is_correct  \
# 1795           D  Ku-Ring-Gai          \nD                D        True
# 1796           A   Sutherland          \nA                A        True
# 1797           A    Warringah          \nB                B       False
# 1798           B    Lane Cove          \nC                C       False
# 1799           D   Parramatta          \nC                C       False
#
#       error           started_at          finished_at
# 1795    NaN  2026-07-10T16:14:47  2026-07-10T16:14:47
# 1796    NaN  2026-07-10T16:14:50  2026-07-10T16:14:50
# 1797    NaN  2026-07-10T16:14:53  2026-07-10T16:14:53
# 1798    NaN  2026-07-10T16:14:56  2026-07-10T16:14:56
# 1799    NaN  2026-07-10T16:14:59  2026-07-10T16:14:59

# %%
# ============================================================
# Task 5 metric verification:
# Gemma 2 27B
# ============================================================

import os
import glob
import pandas as pd

from sklearn.metrics import (
    accuracy_score,
    f1_score,
    recall_score
)

# ------------------------------------------------------------
# 1. Find all possible Gemma 2 27B CSV files
# ------------------------------------------------------------

output_folder = "region_sensitivity_eval_outputs"

candidate_files = sorted(
    glob.glob(
        os.path.join(
            output_folder,
            "*gemma*27b*.csv"
        )
    ),
    key=os.path.getmtime,
    reverse=True
)

print("All possible Gemma 2 27B files:\n")

valid_result_files = []

for i, path in enumerate(candidate_files):
    try:
        temp_df = pd.read_csv(path)

        print("=" * 90)
        print(f"[{i}] {os.path.basename(path)}")
        print("Modified:", pd.Timestamp(os.path.getmtime(path), unit="s"))
        print("Shape:", temp_df.shape)
        print("Columns:", temp_df.columns.tolist())

        if "model_name" in temp_df.columns:
            print("Model names:")
            print(
                temp_df["model_name"]
                .value_counts(dropna=False)
                .head()
            )

        required_columns = {
            "gold_answer",
            "predicted_answer",
            "task_type"
        }

        if required_columns.issubset(temp_df.columns):
            print("STATUS: Valid row-level result file")
            valid_result_files.append(path)
        else:
            print("STATUS: Skipped because this appears to be a summary file")

    except Exception as error:
        print("=" * 90)
        print(f"[{i}] {os.path.basename(path)}")
        print("Could not read file:", error)

if len(valid_result_files) == 0:
    raise FileNotFoundError(
        "No row-level Gemma 2 27B result CSV was found.\n"
        "A valid file must contain gold_answer, predicted_answer "
        "and task_type."
    )

# Select the most recently modified valid row-level result file
file_path = valid_result_files[0]

print("\n" + "=" * 90)
print("SELECTED FINAL RESULT FILE")
print("=" * 90)
print(file_path)


# ------------------------------------------------------------
# 2. Load selected result file
# ------------------------------------------------------------

df = pd.read_csv(file_path)

print("\nShape:")
print(df.shape)

print("\nColumns:")
print(df.columns.tolist())

if "model_name" in df.columns:
    print("\nModel names recorded in the CSV:")
    print(df["model_name"].value_counts(dropna=False))


# ------------------------------------------------------------
# 3. Confirm this really is Gemma 2 27B
# ------------------------------------------------------------

if "model_name" in df.columns:
    model_name_text = " ".join(
        df["model_name"]
        .dropna()
        .astype(str)
        .str.lower()
        .unique()
    )

    if "gemma" not in model_name_text:
        raise ValueError(
            "The selected file does not appear to contain Gemma results."
        )

    if "27b" not in model_name_text:
        print(
            "\nWARNING: The model_name field does not explicitly contain "
            "'27b'. Please inspect the model name above."
        )


# ------------------------------------------------------------
# 4. Standardise answers and task types
# ------------------------------------------------------------

def clean_answer(value):
    """
    Keep only valid extracted answer positions A, B, C or D.
    """
    if pd.isna(value):
        return None

    answer = str(value).strip().upper()

    if answer in ["A", "B", "C", "D"]:
        return answer

    return None


df["gold_clean"] = df["gold_answer"].apply(clean_answer)
df["pred_clean"] = df["predicted_answer"].apply(clean_answer)

df["task_clean"] = (
    df["task_type"]
    .astype(str)
    .str.strip()
    .str.lower()
    .str.replace("-", "_", regex=False)
    .str.replace(" ", "_", regex=False)
)

valid_df = df[
    df["gold_clean"].isin(["A", "B", "C", "D"])
    & df["pred_clean"].isin(["A", "B", "C", "D"])
].copy()


# ------------------------------------------------------------
# 5. Basic checks
# ------------------------------------------------------------

print("\n" + "=" * 70)
print("BASIC CHECK")
print("=" * 70)

print("Total rows:", len(df))
print("Valid rows:", len(valid_df))
print("Invalid or empty predictions:", len(df) - len(valid_df))

if "error" in df.columns:
    error_mask = (
        df["error"].notna()
        & df["error"].astype(str).str.strip().ne("")
    )

    print("Rows with error:", int(error_mask.sum()))

print("\nTask counts in all rows:")
print(df["task_clean"].value_counts(dropna=False))

print("\nTask counts in valid rows:")
print(valid_df["task_clean"].value_counts(dropna=False))

if len(valid_df) == 0:
    raise ValueError(
        "The selected Gemma CSV contains no valid A/B/C/D predictions."
    )


# ------------------------------------------------------------
# 6. Overall Accuracy and Macro-F1
# ------------------------------------------------------------

y_true = valid_df["gold_clean"]
y_pred = valid_df["pred_clean"]

overall_accuracy = accuracy_score(
    y_true,
    y_pred
)

overall_macro_f1 = f1_score(
    y_true,
    y_pred,
    labels=["A", "B", "C", "D"],
    average="macro",
    zero_division=0
)

print("\n" + "=" * 70)
print("OVERALL RESULTS")
print("=" * 70)

print(f"Accuracy check: {overall_accuracy * 100:.2f}%")
print(f"Overall Macro-F1: {overall_macro_f1 * 100:.2f}%")


# ------------------------------------------------------------
# 7. Accuracy and Macro-F1 by question type
# ------------------------------------------------------------

task_settings = {
    "pairwise_comparison": ["A", "B"],
    "top_sensitive_region": ["A", "B", "C", "D"],
    "management_priority": ["A", "B", "C", "D"]
}

task_rows = []

for task_name, labels in task_settings.items():

    task_df = valid_df[
        valid_df["task_clean"] == task_name
    ].copy()

    if len(task_df) == 0:
        task_accuracy = None
        task_macro_f1 = None

    else:
        task_accuracy = accuracy_score(
            task_df["gold_clean"],
            task_df["pred_clean"]
        )

        task_macro_f1 = f1_score(
            task_df["gold_clean"],
            task_df["pred_clean"],
            labels=labels,
            average="macro",
            zero_division=0
        )

    task_rows.append({
        "Task Type": task_name,
        "Valid Rows": len(task_df),
        "Accuracy (%)": (
            round(task_accuracy * 100, 2)
            if task_accuracy is not None
            else None
        ),
        "Macro-F1 (%)": (
            round(task_macro_f1 * 100, 2)
            if task_macro_f1 is not None
            else None
        )
    })

task_table = pd.DataFrame(task_rows)

print("\n" + "=" * 70)
print("RESULTS BY QUESTION TYPE")
print("=" * 70)

display(task_table)


# ------------------------------------------------------------
# 8. Option-level Recall and F1
# ------------------------------------------------------------

options = ["A", "B", "C", "D"]

recall_values = recall_score(
    y_true,
    y_pred,
    labels=options,
    average=None,
    zero_division=0
)

f1_values = f1_score(
    y_true,
    y_pred,
    labels=options,
    average=None,
    zero_division=0
)

option_table = pd.DataFrame({
    "Option": options,
    "Recall (%)": [
        round(value * 100, 2)
        for value in recall_values
    ],
    "F1 (%)": [
        round(value * 100, 2)
        for value in f1_values
    ]
})

print("\n" + "=" * 70)
print("OPTION-LEVEL RECALL AND F1")
print("=" * 70)

display(option_table)


# ------------------------------------------------------------
# 9. Prediction distribution
# ------------------------------------------------------------

prediction_counts = (
    y_pred.value_counts()
    .reindex(options, fill_value=0)
)

distribution_table = pd.DataFrame({
    "Option": options,
    "Prediction Count": [
        int(prediction_counts[option])
        for option in options
    ],
    "Prediction Percentage (%)": [
        round(
            prediction_counts[option] / len(valid_df) * 100,
            2
        )
        for option in options
    ]
})

print("\n" + "=" * 70)
print("PREDICTION DISTRIBUTION")
print("=" * 70)

display(distribution_table)


# ------------------------------------------------------------
# 10. Consistency check against stored is_correct
# ------------------------------------------------------------

if "is_correct" in df.columns:
    stored_accuracy = pd.to_numeric(
        df.loc[valid_df.index, "is_correct"],
        errors="coerce"
    ).mean()

    print("\n" + "=" * 70)
    print("CONSISTENCY CHECK")
    print("=" * 70)

    print(
        f"Accuracy recalculated from answers: "
        f"{overall_accuracy * 100:.2f}%"
    )

    print(
        f"Accuracy from stored is_correct: "
        f"{stored_accuracy * 100:.2f}%"
    )

    print(
        f"Difference: "
        f"{abs(overall_accuracy - stored_accuracy) * 100:.6f} "
        "percentage points"
    )
# Out:
# All possible Gemma 2 27B files:
#
# ==========================================================================================
# [0] model_accuracy_summary_openrouter_gemma2_27b_promptmatched.csv
# Modified: 2026-07-10 07:31:49.638308048
# Shape: (4, 9)
# Columns: ['model_provider', 'model_name', 'task_type', 'total_rows', 'successful_rows', 'error_rows', 'accuracy_valid_only', 'accuracy_errors_as_wrong', 'output_file']
# Model names:
# model_name
# google/gemma-2-27b-it    4
# Name: count, dtype: int64
# STATUS: Skipped because this appears to be a summary file
# ==========================================================================================
# [1] results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv
# Modified: 2026-07-10 07:12:57.765226364
# Shape: (1800, 13)
# Columns: ['id', 'task_type', 'weather_condition', 'model_provider', 'model_name', 'gold_answer', 'gold_region', 'raw_response', 'predicted_answer', 'is_correct', 'error', 'started_at', 'finished_at']
# Model names:
# model_name
# google/gemma-2-27b-it    1800
# Name: count, dtype: int64
# STATUS: Valid row-level result file
#
# ==========================================================================================
# SELECTED FINAL RESULT FILE
# ==========================================================================================
# region_sensitivity_eval_outputs/results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv
#
# Shape:
# (1800, 13)
#
# Columns:
# ['id', 'task_type', 'weather_condition', 'model_provider', 'model_name', 'gold_answer', 'gold_region', 'raw_response', 'predicted_answer', 'is_correct', 'error', 'started_at', 'finished_at']
#
# Model names recorded in the CSV:
# model_name
# google/gemma-2-27b-it    1800
# Name: count, dtype: int64
#
# ======================================================================
# BASIC CHECK
# ======================================================================
# Total rows: 1800
# Valid rows: 1800
# Invalid or empty predictions: 0
# Rows with error: 0
#
# Task counts in all rows:
# task_clean
# management_priority     600
# pairwise_comparison     600
# top_sensitive_region    600
# Name: count, dtype: int64
#
# Task counts in valid rows:
# task_clean
# management_priority     600
# pairwise_comparison     600
# top_sensitive_region    600
# Name: count, dtype: int64
#
# ======================================================================
# OVERALL RESULTS
# ======================================================================
# Accuracy check: 60.72%
# Overall Macro-F1: 58.52%
#
# ======================================================================
# RESULTS BY QUESTION TYPE
# ======================================================================
#               Task Type  Valid Rows  Accuracy (%)  Macro-F1 (%)
# 0   pairwise_comparison         600         76.00         76.00
# 1  top_sensitive_region         600         52.00         51.97
# 2   management_priority         600         54.17         54.05
# ======================================================================
# OPTION-LEVEL RECALL AND F1
# ======================================================================
#   Option  Recall (%)  F1 (%)
# 0      A       64.29   65.62
# 1      B       64.64   64.01
# 2      C       51.37   50.59
# 3      D       54.23   53.85
# ======================================================================
# PREDICTION DISTRIBUTION
# ======================================================================
#   Option  Prediction Count  Prediction Percentage (%)
# 0      A               591                      32.83
# 1      B               620                      34.44
# 2      C               301                      16.72
# 3      D               288                      16.00
# ======================================================================
# CONSISTENCY CHECK
# ======================================================================
# Accuracy recalculated from answers: 60.72%
# Accuracy from stored is_correct: 60.72%
# Difference: 0.000000 percentage points

# %% [markdown]
# ## 15. Final summary

# %%
# -----------------------------
# Final summary
# -----------------------------

results_df = pd.read_csv(SAVE_PATH)

# Normalise error field.
results_df["error_clean"] = results_df["error"].fillna("").astype(str).str.strip()
valid_df = results_df[results_df["error_clean"] == ""].copy()

# Normalise correctness after loading CSV.
results_df["is_correct_bool"] = results_df["is_correct"].astype(str).str.lower().isin(["true", "1", "yes"])
valid_df["is_correct_bool"] = valid_df["is_correct"].astype(str).str.lower().isin(["true", "1", "yes"])

print("Model provider:", MODEL_PROVIDER)
print("Model name:", MODEL_NAME)
print("Output:", SAVE_PATH)
print("Total saved rows:", len(results_df))
print("Successful rows:", len(valid_df))
print("Error rows:", len(results_df) - len(valid_df))

print("\nAccuracy, valid-only:")
print(valid_df["is_correct_bool"].mean() if len(valid_df) > 0 else None)

print("\nAccuracy, errors as wrong:")
print(results_df["is_correct_bool"].mean() if len(results_df) > 0 else None)

print("\nTask-level summary:")
summary = (
    results_df
    .assign(success=lambda x: x["error_clean"] == "")
    .groupby("task_type")
    .agg(
        total_rows=("id", "count"),
        successful_rows=("success", "sum"),
        accuracy_errors_as_wrong=("is_correct_bool", "mean"),
    )
    .reset_index()
)

valid_summary = (
    valid_df
    .groupby("task_type")
    .agg(accuracy_valid_only=("is_correct_bool", "mean"))
    .reset_index()
)

summary = summary.merge(valid_summary, on="task_type", how="left")
display(summary)
# Out:
# Model provider: openrouter
# Model name: google/gemma-2-27b-it
# Output: region_sensitivity_eval_outputs/results_google_gemma-2-27b-it_context_v2_1800_promptmatched.csv
# Total saved rows: 1800
# Successful rows: 1800
# Error rows: 0
#
# Accuracy, valid-only:
# 0.6072222222222222
#
# Accuracy, errors as wrong:
# 0.6072222222222222
#
# Task-level summary:
#               task_type  total_rows  successful_rows  \
# 0   management_priority         600              600
# 1   pairwise_comparison         600              600
# 2  top_sensitive_region         600              600
#
#    accuracy_errors_as_wrong  accuracy_valid_only
# 0                  0.541667             0.541667
# 1                  0.760000             0.760000
# 2                  0.520000             0.520000

# %% [markdown]
# ## 16. Save compact summary CSV

# %%
# -----------------------------
# Save compact model summary
# -----------------------------

summary_rows = []

results_df = pd.read_csv(SAVE_PATH)
results_df["error_clean"] = results_df["error"].fillna("").astype(str).str.strip()
results_df["success"] = results_df["error_clean"] == ""
results_df["is_correct_bool"] = results_df["is_correct"].astype(str).str.lower().isin(["true", "1", "yes"])

valid_df = results_df[results_df["success"]].copy()

summary_rows.append({
    "model_provider": MODEL_PROVIDER,
    "model_name": MODEL_NAME,
    "task_type": "overall",
    "total_rows": len(results_df),
    "successful_rows": int(results_df["success"].sum()),
    "error_rows": int((~results_df["success"]).sum()),
    "accuracy_valid_only": valid_df["is_correct_bool"].mean() if len(valid_df) > 0 else None,
    "accuracy_errors_as_wrong": results_df["is_correct_bool"].mean() if len(results_df) > 0 else None,
    "output_file": str(SAVE_PATH),
})

for task_value, sub in results_df.groupby("task_type"):
    sub_valid = sub[sub["success"]].copy()

    summary_rows.append({
        "model_provider": MODEL_PROVIDER,
        "model_name": MODEL_NAME,
        "task_type": task_value,
        "total_rows": len(sub),
        "successful_rows": int(sub["success"].sum()),
        "error_rows": int((~sub["success"]).sum()),
        "accuracy_valid_only": sub_valid["is_correct_bool"].mean() if len(sub_valid) > 0 else None,
        "accuracy_errors_as_wrong": sub["is_correct_bool"].mean() if len(sub) > 0 else None,
        "output_file": str(SAVE_PATH),
    })

model_summary_df = pd.DataFrame(summary_rows)

SUMMARY_PATH = (
    EVAL_OUTPUT_DIR
    / "model_accuracy_summary_openrouter_gemma2_27b_promptmatched.csv"
)

model_summary_df.to_csv(SUMMARY_PATH, index=False)

print("Saved summary:", SUMMARY_PATH)
print("Absolute path:", SUMMARY_PATH.resolve())
print("Exists:", SUMMARY_PATH.exists())

display(model_summary_df)
# Out:
# Saved summary: region_sensitivity_eval_outputs/model_accuracy_summary_openrouter_gemma2_27b_promptmatched.csv
# Absolute path: /Users/tanghuiru/Desktop/labeled_data_v1/region_sensitivity_eval_outputs/model_accuracy_summary_openrouter_gemma2_27b_promptmatched.csv
# Exists: True
#   model_provider             model_name             task_type  total_rows  \
# 0     openrouter  google/gemma-2-27b-it               overall        1800
# 1     openrouter  google/gemma-2-27b-it   management_priority         600
# 2     openrouter  google/gemma-2-27b-it   pairwise_comparison         600
# 3     openrouter  google/gemma-2-27b-it  top_sensitive_region         600
#
#    successful_rows  error_rows  accuracy_valid_only  accuracy_errors_as_wrong  \
# 0             1800           0             0.607222                  0.607222
# 1              600           0             0.541667                  0.541667
# 2              600           0             0.760000                  0.760000
# 3              600           0             0.520000                  0.520000
#
#                                          output_file
# 0  region_sensitivity_eval_outputs/results_google...
# 1  region_sensitivity_eval_outputs/results_google...
# 2  region_sensitivity_eval_outputs/results_google...
# 3  region_sensitivity_eval_outputs/results_google...
